# %% [markdown]
# # Loading Data

# %%
import pandas as pd
poke = pd.read_csv("pokemon_data.csv")
print(poke)
# Out:
# #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
poke.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
poke.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
#if file is in other format
#xl=pd.read_excel("pandas-master/pokemon_data.xlsx")
pd.read_csv("pandas-master/pokemon_data.txt")
# Out:
#     #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0    1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1    2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2    3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3    3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4    4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...
# ..                                                 ...
# 795  719\tDiancie\tRock\tFairy\t50\t100\t150\t100\t...
# 796  719\tDiancieMega Diancie\tRock\tFairy\t50\t160...
# 797  720\tHoopaHoopa Confined\tPsychic\tGhost\t80\t...
# 798  720\tHoopaHoopa Unbound\tPsychic\tDark\t80\t16...
# 799  721\tVolcanion\tFire\tWater\t80\t110\t120\t130...
#
# [800 rows x 1 columns]

# %%
pd.read_csv("pandas-master/pokemon_data.txt",delimiter="\t") # to remove tab which we got before by using only read_csv format
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # Reading Data in Pandas

# %%
# reading headers
#print(poke.columns)
# read each column
#print(poke[['Name', 'Type 1', 'HP']])
# read each row
#print(poke.head(4))
# To read specific row
#print(poke.iloc[2])
#if we need specific data from particular row
#print(poke.iloc[2][:4]) # we are looking for data of only first 3 column of 3 row
#print(poke.iloc[1][2:5])

# Read specific location

print(poke.iloc[2,1])
# Out:
# Venusaur

# %%
#for index, row in poke.iterrows():
#    print(index,row)
# here i am accessing only requird information from data, in this case i am only reading names 
#for index, row in poke.iterrows():
    #print(index,row["Name"])

# for multiple infromartion

#for index, row in poke.iterrows():
   # print (index, row["HP"],row["Name"])

# %%
poke.loc[poke['Type 1']=="Fire"]# require specific information
poke.loc[poke['Name']=="Ivysaur"]#
# Out:
#    #     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2  Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 1           1      False

# %%
poke.describe
# Out:
# <bound method NDFrame.describe of        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke.sort_values("Name")
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke.sort_values("Name",ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# for multiple column for sorting
poke.sort_values(["Type 1", "Name"],ascending=[False,True])
# Out:
#        #                 Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 655  594            Alomomola  Water     NaN  165      75       80       40
# 199  184            Azumarill  Water   Fairy  100      50       80       60
# 371  339             Barboach  Water  Ground   50      48       43       46
# 610  550             Basculin  Water     NaN   70      92       65       80
# 11     9            Blastoise  Water     NaN   79      83      100       85
# ..   ...                  ...    ...     ...  ...     ...      ...      ...
# 459  413  WormadamSandy Cloak    Bug  Ground   60      79      105       59
# 460  413  WormadamTrash Cloak    Bug   Steel   60      69       95       69
# 288  265              Wurmple    Bug     NaN   45      45       35       20
# 208  193                Yanma    Bug  Flying   65      65       45       75
# 520  469              Yanmega    Bug  Flying   86      76       86      116
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke.sort_values(["Type 1", "Name"],ascending=[1,0]) # we can use 1 and 0 instead of true and false
# Out:
#        #                 Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 520  469              Yanmega    Bug  Flying   86      76       86      116
# 208  193                Yanma    Bug  Flying   65      65       45       75
# 288  265              Wurmple    Bug     NaN   45      45       35       20
# 460  413  WormadamTrash Cloak    Bug   Steel   60      69       95       69
# 459  413  WormadamSandy Cloak    Bug  Ground   60      79      105       59
# ..   ...                  ...    ...     ...  ...     ...      ...      ...
# 11     9            Blastoise  Water     NaN   79      83      100       85
# 610  550             Basculin  Water     NaN   70      92       65       80
# 371  339             Barboach  Water  Ground   50      48       43       46
# 199  184            Azumarill  Water   Fairy  100      50       80       60
# 655  594            Alomomola  Water     NaN  165      75       80       40
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# #  Making changes in data

# %%
poke.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# we want to find total of all data and add one more column in data set 
poke["Total"]=poke["HP"]+ poke["Attack"]+ poke["Defense"]+ poke["Sp. Atk"]+ poke["Speed"]+ poke["Sp. Def"]
poke.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#we can do the same with following
# to remove total column
poke.drop(columns="Total")
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
poke["Total"] = poke.iloc[:,4:10].sum(axis=1)
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
poke["Mean"] = poke.iloc[:,4:10].mean(axis=1)
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total        Mean
# ...

# %%
# to reorder my column
cols=list(poke.columns)
poke = poke[cols[0:4]+[cols[-2]]+cols[4:12]+[cols[-1]]]
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # saving dataframe

# %%
poke.to_csv("ds.csv")

# %%
#to avoid printing index 
#poke.to_csv("ds.csv",index=False)
#poke.to_latex("ds.tex",index=False)

# %%
poke.to_csv("ds.txt",index=False, sep="\t")

# %% [markdown]
# # filtering data

# %%
poke.loc[poke["Type 1"]=="Grass"]
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48    43                 Oddish  Grass    Poison    320   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
# ...

# %%
poke.loc[(poke["Type 1"]=="Grass") & (poke["Type 2"]=="Poison")] # we can also use 'and' instead of &
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# ...

# %%
new_poke=poke.loc[(poke["Type 1"]=="Grass") & (poke["Type 2"]=="Poison") & (poke["HP"]>70)]

# %%
new_poke
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 652  591              Amoonguss  Grass  Poison    464  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary        Mean
# 2        100      100     80           1      False   87.500000
# 3        122      120     80           1      False  104.166667
# 50       110       90     50           1      False   81.666667
# 77       100       70     70           1      False   81.666667
# 652       85       80     30           5      False   77.333333

# %%
new_poke.to_csv("new_poke.csv")

# %%
new_poke
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 652  591              Amoonguss  Grass  Poison    464  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary        Mean
# 2        100      100     80           1      False   87.500000
# 3        122      120     80           1      False  104.166667
# 50       110       90     50           1      False   81.666667
# 77       100       70     70           1      False   81.666667
# 652       85       80     30           5      False   77.333333

# %%
# check with index its same as old
new_poke=new_poke.reset_index()
new_poke
# Out:
#    index    #                   Name Type 1  Type 2  Total   HP  Attack  \
# 0      2    3               Venusaur  Grass  Poison    525   80      82
# 1      3    3  VenusaurMega Venusaur  Grass  Poison    625   80     100
# 2     50   45              Vileplume  Grass  Poison    490   75      80
# 3     77   71             Victreebel  Grass  Poison    490   80     105
# 4    652  591              Amoonguss  Grass  Poison    464  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary        Mean
# 0       83      100      100     80           1      False   87.500000
# 1      123      122      120     80           1      False  104.166667
# 2       85      110       90     50           1      False   81.666667
# 3       65      100       70     70           1      False   81.666667
# 4       70       85       80     30           5      False   77.333333

# %%
# to avoid getting last saved index also
new_poke.reset_index(drop=True,inplace=True)

# %%
new_poke
# Out:
#    index    #                   Name Type 1  Type 2  Total   HP  Attack  \
# 0      2    3               Venusaur  Grass  Poison    525   80      82
# 1      3    3  VenusaurMega Venusaur  Grass  Poison    625   80     100
# 2     50   45              Vileplume  Grass  Poison    490   75      80
# 3     77   71             Victreebel  Grass  Poison    490   80     105
# 4    652  591              Amoonguss  Grass  Poison    464  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary        Mean
# 0       83      100      100     80           1      False   87.500000
# 1      123      122      120     80           1      False  104.166667
# 2       85      110       90     50           1      False   81.666667
# 3       65      100       70     70           1      False   81.666667
# 4       70       85       80     30           5      False   77.333333

# %%
#filter name
poke.loc[poke["Name"].str.contains("Mega")]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
# for not in data 
poke.loc[~poke["Name"].str.contains("Mega")] # we drop all name with mega
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
# ...

# %%
# use contain wih more powerful way
import re
poke.loc[poke["Type 1"].str.contains("Fire|Grass",regex=True)]# we sorted data with type as grass or fire
# to order capitalisation of words
poke.loc[poke["Type 1"].str.contains("fire|grass",flags=re.I,regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
# ...

# %%
#name which include pi
poke.loc[poke["Name"].str.contains("pi[a-z]*",flags=re.I,regex=True)]
# name with start Pi always
poke.loc[poke["Name"].str.contains("^pi[a-z]*",flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %% [markdown]
# # Conditional changes

# %%
poke.loc[poke['Type 1']=='Fire', 'Type 1'] = "Flamer"
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Flamer   Water    600  80     110      120
#
# ...

# %%
poke.loc[poke['Type 1']=='Flamer', 'Type 1'] = "Fire"

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# we can do this changes for any column
poke.loc[poke["Type 1"]=="Fire", "Legendary"]=True
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# for conditional change in mulstiple column
import pandas as pd
poke=pd.read_csv("pokemon_data.csv")
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
poke["Total"]=poke.iloc[:,4:10].sum(axis=1)
poke.to_csv("new_poke.csv")
poke
poke.loc[poke['Total']>500,['Generation','Legendary']]='Test value'

# %%
poke.loc[poke['Total']>500,['Generation','Legendary']]=['Test 1' , 'Test 2']
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary  Total
# 0         65       65     45          1     False    318
# ...

# %% [markdown]
# # Aggreagte Stastics(Groupby)

# %%
poke = pd.read_csv("new_poke.csv")
poke
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  HP  Attack  \
# 0             0    1              Bulbasaur    Grass  Poison  45      49
# 1             1    2                Ivysaur    Grass  Poison  60      62
# 2             2    3               Venusaur    Grass  Poison  80      82
# 3             3    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4             4    4             Charmander     Fire     NaN  39      52
# ..          ...  ...                    ...      ...     ...  ..     ...
# 795         795  719                Diancie     Rock   Fairy  50     100
# 796         796  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799         799  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation   Legendary  Total
# ...

# %%
poke
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  HP  Attack  \
# 0             0    1              Bulbasaur    Grass  Poison  45      49
# 1             1    2                Ivysaur    Grass  Poison  60      62
# 2             2    3               Venusaur    Grass  Poison  80      82
# 3             3    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4             4    4             Charmander     Fire     NaN  39      52
# ..          ...  ...                    ...      ...     ...  ..     ...
# 795         795  719                Diancie     Rock   Fairy  50     100
# 796         796  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799         799  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation   Legendary  Total
# ...

# %%
# poke.groupby(["Type 1"]).mean().sort_values("Attack",ascending=False)
poke.groupby(['Type 1']).sum()
# Out:
#           Unnamed: 0      #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug            25397  23080  3925    4897     4880     3717     4471   4256
# Dark           15729  14302  2071    2740     2177     2314     2155   2361
# Dragon         16699  15180  2666    3588     2764     3099     2843   2657
# Electric       17626  15994  2631    3040     2917     3961     3243   3718
# Fairy           8407   7642  1260    1046     1117     1335     1440    826
# Fighting       10812   9824  1886    2613     1780     1434     1747   1784
# Fire           18769  17025  3635    4408     3524     4627     3755   3871
# Flying          2986   2711   283     315      265      377      290    410
# Ghost          17161  15568  2062    2361     2598     2539     2447   2059
# Grass          26629  24141  4709    5125     4956     5425     4930   4335
# Ground         12554  11401  2361    3064     2715     1807     2008   2045
# ...

# %%
poke.groupby(["Type 1"]).count()
# Out:
#           Unnamed: 0    #  Name  Type 2   HP  Attack  Defense  Sp. Atk  \
# Type 1
# Bug               69   69    69      52   69      69       69       69
# Dark              31   31    31      21   31      31       31       31
# Dragon            32   32    32      21   32      32       32       32
# Electric          44   44    44      17   44      44       44       44
# Fairy             17   17    17       2   17      17       17       17
# Fighting          27   27    27       7   27      27       27       27
# Fire              52   52    52      24   52      52       52       52
# Flying             4    4     4       2    4       4        4        4
# Ghost             32   32    32      22   32      32       32       32
# Grass             70   70    70      37   70      70       70       70
# Ground            32   32    32      19   32      32       32       32
# Ice               24   24    24      11   24      24       24       24
# ...

# %%
poke["Count"]=1
poke.groupby(["Type 1"]).count()['Count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Count, dtype: int64

# %%
#for subcounts
poke.groupby(["Type 1","Type 2"]).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %% [markdown]
# # Working with large amount of data

# %%
new_data=pd.DataFrame(columns=poke.columns)

for poke in  pd.read_csv("new_poke.csv",chunksize=5):
    results = poke.groupby(["Type 1"]).count()
    new_data = pd.concat([new_data,results])
#new_data
  #  print("CHUNk DF")
    # print(poke)
# Out:
#         Unnamed: 0  # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def  \
# Fire             1  1    1    NaN      0  1      1       1       1       1
# Grass            4  4    4    NaN      4  4      4       4       4       4
# Fire             4  4    4    NaN      3  4      4       4       4       4
# Water            1  1    1    NaN      0  1      1       1       1       1
# Bug              2  2    2    NaN      0  2      2       2       2       2
# ...            ... ..  ...    ...    ... ..    ...     ...     ...     ...
# Fairy            1  1    1    NaN      0  1      1       1       1       1
# Flying           2  2    2    NaN      2  2      2       2       2       2
# Fire             1  1    1    NaN      1  1      1       1       1       1
# Psychic          2  2    2    NaN      2  2      2       2       2       2
# Rock             2  2    2    NaN      2  2      2       2       2       2
#
#         Speed Generation Legendary Total
# ...
